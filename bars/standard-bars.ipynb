# %% [markdown]
# # Build Standard Bars(Time Bar, Tick Bar, Volume Bar and Dollar Bar)

# %%
import gc
import glob
import os
from operator import itemgetter
from typing import Dict, List, Tuple

import dask.bag as db
import numpy as np
import pandas as pd
from dask.diagnostics import ProgressBar

# %%
from utils import aggregate, aggregate_trade, convert_to_bar

# %%
aggregate(pd.Series([3,2,1,4,5,6]))
# Out:
# {'open': 3, 'high': 6, 'low': 1, 'close': 6, 'mean': 3.5, 'median': 3.5}

# %%
total_volume = pd.read_csv('/data/csv/OKEx.Swap.XMR_USDT.csv', usecols=['quantity']).sum()

# %% [markdown]
# ## Build on a single CSV file

# %%
def build_bars_internal(grouped: pd.core.groupby.DataFrameGroupBy, bar_type: str, bar_size: int, output_csv_file: str)->None:
    series = grouped.apply(lambda df: convert_to_bar(bar_type, bar_size, df))  # parallel_apply, from pandarallel
    
    bars_df = pd.DataFrame(list(series))

    os.makedirs(os.path.dirname(output_csv_file), exist_ok=True)
    bars_df.to_csv(output_csv_file, index=False)
    # optional
    del bars_df
    del series
    gc.collect()

# %%
def build_standard_bars(input_csv_file: str, bar_type:str, bar_size: np.int64, output_csv_file: str)->None:
    assert bar_type == 'TimeBar' or bar_type == 'TickBar' or bar_type == 'VolumeBar' or bar_type == 'DollarBar'
    df = pd.read_csv(input_csv_file, engine='c',
                     dtype={'exchange': 'category', 'marketType': 'category', 'pair': 'category',
                            'timestamp': 'int64', 'price': 'float32',
                            'quantity': 'float32', 'side': 'bool', 'trade_id': 'string'})
    if bar_type == 'TimeBar':
        grouped = df.groupby(df['timestamp'] // bar_size)
    elif bar_type == 'TickBar':
        grouped = df.groupby(df.index // bar_size)
    elif bar_type == 'VolumeBar':
        series = df['quantity'].astype('float64').cumsum().floordiv(bar_size).astype('uint32')
        grouped = df.groupby(series)
    elif bar_type == 'DollarBar':
        series = (df['quantity'] * df['price']).astype('float64').cumsum().floordiv(bar_size).astype('uint32')
        grouped = df.groupby(series)

    build_bars_internal(grouped, bar_type, bar_size, output_csv_file)
    del df
    del grouped
    gc.collect()

# %%
build_standard_bars('/data/csv/OKEx.Swap.XMR_USDT.csv', 'TimeBar', 10000, '/data/bars/TimeBar/10000/TimeBar.10000.OKEx.Swap.XMR_USDT.csv')

# %%
time_bars = pd.read_csv('/data/bars/TimeBar/10000/TimeBar.10000.OKEx.Swap.XMR_USDT.csv')

# %%
time_bars.head()
# Out:
#   exchange market_type      pair bar_type  bar_size      timestamp  \
# 0     OKEx        Swap  XMR_USDT  TimeBar     10000  1590216460000
# 1     OKEx        Swap  XMR_USDT  TimeBar     10000  1590220810000
# 2     OKEx        Swap  XMR_USDT  TimeBar     10000  1590221700000
# 3     OKEx        Swap  XMR_USDT  TimeBar     10000  1590229370000
# 4     OKEx        Swap  XMR_USDT  TimeBar     10000  1590249610000
#
#    timestamp_end       open       high        low  ...  volume  volume_sell  \
# 0  1590216470000  63.419998  63.419998  63.419998  ...     2.8          2.8
# 1  1590220820000  63.560001  63.560001  63.560001  ...     0.7          0.0
# 2  1590221710000  63.070000  63.070000  63.070000  ...     0.6          0.6
# 3  1590229380000  62.410000  62.410000  62.410000  ...     1.5          1.5
# 4  1590249620000  63.490002  63.490002  63.490002  ...     0.5          0.0
#
#    volume_buy  volume_quote  volume_quote_sell  volume_quote_buy       vwap  \
# 0         0.0    177.575989         177.575989          0.000000  63.419998
# 1         0.7     44.492001           0.000000         44.492001  63.560001
# 2         0.0     37.842003          37.842003          0.000000  63.070004
# 3         0.0     93.614998          93.614998          0.000000  62.410000
# 4         0.5     31.745001           0.000000         31.745001  63.490002
#
#    count  count_sell  count_buy
# 0      1           1          0
# 1      1           0          1
# 2      1           1          0
# 3      1           1          0
# 4      1           0          1
#
# [5 rows x 23 columns]

# %%
time_bars['volume'].sum()/total_volume
# Out:
# quantity    1.0
# dtype: float64

# %%
build_standard_bars('/data/csv/OKEx.Swap.XMR_USDT.csv', 'TickBar', 4, '/data/bars/TickBar/4/TickBar.4.OKEx.Swap.XMR_USDT.csv')

# %%
tick_bars = pd.read_csv('/data/bars/TickBar/4/TickBar.4.OKEx.Swap.XMR_USDT.csv')

# %%
tick_bars.head()
# Out:
#   exchange market_type      pair bar_type  bar_size      timestamp  \
# 0     OKEx        Swap  XMR_USDT  TickBar         4  1590216461309
# 1     OKEx        Swap  XMR_USDT  TickBar         4  1590249619582
# 2     OKEx        Swap  XMR_USDT  TickBar         4  1590265720050
# 3     OKEx        Swap  XMR_USDT  TickBar         4  1590293593504
# 4     OKEx        Swap  XMR_USDT  TickBar         4  1590295679230
#
#    timestamp_end       open       high        low  ...  volume  volume_sell  \
# 0  1590229378882  63.419998  63.560001  62.410000  ...     5.6          4.9
# 1  1590263779095  63.490002  64.389999  63.490002  ...     1.4          0.0
# 2  1590292415865  64.690002  64.989998  63.220001  ...     5.7          0.7
# 3  1590293777432  63.220001  63.279999  63.220001  ...     8.0          0.0
# 4  1590295691154  63.029999  63.029999  63.020000  ...     4.5          0.0
#
#    volume_buy  volume_quote  volume_quote_sell  volume_quote_buy       vwap  \
# 0         0.7    353.524994         309.032990         44.492001  63.129463
# 1         1.4     89.546005           0.000000         89.546005  63.961433
# 2         5.0    368.411987          44.254002        324.157990  64.633682
# 3         8.0    506.000000           0.000000        506.000000  63.250000
# 4         4.5    283.605988           0.000000        283.605988  63.023552
#
#    count  count_sell  count_buy
# 0      4           3          1
# 1      4           0          4
# 2      4           1          3
# 3      4           0          4
# 4      4           0          4
#
# [5 rows x 23 columns]

# %%
tick_bars['volume'].sum()/total_volume
# Out:
# quantity    1.0
# dtype: float64

# %%
build_standard_bars('/data/csv/OKEx.Swap.XMR_USDT.csv', 'VolumeBar', 10, '/data/bars/VolumeBar/10/VolumeBar.10.OKEx.Swap.XMR_USDT.csv')

# %%
volume_bars = pd.read_csv('/data/bars/VolumeBar/10/VolumeBar.10.OKEx.Swap.XMR_USDT.csv')

# %%
volume_bars.head()
# Out:
#   exchange market_type      pair   bar_type  bar_size      timestamp  \
# 0     OKEx        Swap  XMR_USDT  VolumeBar        10  1590216461309
# 1     OKEx        Swap  XMR_USDT  VolumeBar        10  1590265720050
# 2     OKEx        Swap  XMR_USDT  VolumeBar        10  1590293777431
# 3     OKEx        Swap  XMR_USDT  VolumeBar        10  1590298265847
# 4     OKEx        Swap  XMR_USDT  VolumeBar        10  1590298535853
#
#    timestamp_end       open       high        low  ...     volume  \
# 0  1590265720051  63.419998  64.690002  62.410000  ...   7.400000
# 1  1590293777430  64.830002  64.989998  63.220001  ...  10.900001
# 2  1590298086865  63.279999  63.279999  62.939999  ...  10.100000
# 3  1590298450708  63.000000  63.070000  63.000000  ...  10.900001
# 4  1590298729121  63.049999  63.080002  63.049999  ...   8.000000
#
#    volume_sell  volume_buy  volume_quote  volume_quote_sell  volume_quote_buy  \
# 0          4.9    2.500000    468.946991         309.032990        159.914001
# 1          0.7   10.200001    696.663940          44.254002        652.409973
# 2          0.0   10.100000    636.918030           0.000000        636.918030
# 3          0.0   10.900001    687.206970           0.000000        687.206970
# 4          0.0    8.000000    504.528015           0.000000        504.528015
#
#         vwap  count  count_sell  count_buy
# 0  63.371216      9           3          6
# 1  63.914120      6           1          5
# 2  63.061188      7           0          7
# 3  63.046509      9           0          9
# 4  63.066002      3           0          3
#
# [5 rows x 23 columns]

# %%
volume_bars['volume'].sum()/total_volume
# Out:
# quantity    1.0
# dtype: float64

# %%
build_standard_bars('/data/csv/OKEx.Swap.XMR_USDT.csv', 'DollarBar', 1000, '/data/bars/DollarBar/1000/DollarBar.1000.OKEx.Swap.XMR_USDT.csv')

# %%
dollar_bars = pd.read_csv('/data/bars/DollarBar/1000/DollarBar.1000.OKEx.Swap.XMR_USDT.csv')

# %%
dollar_bars.head()
# Out:
#   exchange market_type      pair   bar_type  bar_size      timestamp  \
# 0     OKEx        Swap  XMR_USDT  DollarBar      1000  1590216461309
# 1     OKEx        Swap  XMR_USDT  DollarBar      1000  1590293593507
# 2     OKEx        Swap  XMR_USDT  DollarBar      1000  1590298282361
# 3     OKEx        Swap  XMR_USDT  DollarBar      1000  1590298814347
# 4     OKEx        Swap  XMR_USDT  DollarBar      1000  1590298995801
#
#    timestamp_end       open       high        low  ...     volume  \
# 0  1590293593505  63.419998  64.989998  62.410000  ...  15.100000
# 1  1590298265848  63.220001  63.279999  62.939999  ...  14.900001
# 2  1590298729121  63.040001  63.080002  63.040001  ...  17.299999
# 3  1590298979247  63.070000  63.070000  63.070000  ...  14.099999
# 4  1590315969751  63.070000  63.689999  63.070000  ...  17.200001
#
#    volume_sell  volume_buy  volume_quote  volume_quote_sell  volume_quote_buy  \
# 0          5.6    9.500000    963.210999         353.286987        609.924011
# 1          0.0   14.900001    940.118042           0.000000        940.118042
# 2          0.0   17.299999   1090.934937           0.000000       1090.934937
# 3          0.0   14.099999    889.286987           0.000000        889.286987
# 4          2.0   15.200001   1086.468994         126.774002        959.694946
#
#         vwap  count  count_sell  count_buy
# 0  63.788807     13           4          9
# 1  63.095169     10           0         10
# 2  63.059826     11           0         11
# 3  63.070004      4           0          4
# 4  63.166798     15           3         12
#
# [5 rows x 23 columns]

# %%
dollar_bars['volume'].sum()/total_volume
# Out:
# quantity    1.0
# dtype: float64

# %%
os.remove('/data/bars/TimeBar/10000/TimeBar.10000.OKEx.Swap.XMR_USDT.csv')
os.remove('/data/bars/TickBar/4/TickBar.4.OKEx.Swap.XMR_USDT.csv')
os.remove('/data/bars/VolumeBar/10/VolumeBar.10.OKEx.Swap.XMR_USDT.csv')
os.remove('/data/bars/DollarBar/1000/DollarBar.1000.OKEx.Swap.XMR_USDT.csv')

# %% [markdown]
# ## Build on multiple CSV files

# %%
def generate_tasks(csv_files: List[str], bar_type: str, bar_sizes: List[int], output_dir: str)->List[Tuple[str, str, int, str]]:
    tasks = [(file, bar_type, bar_size, os.path.join(output_dir, str(bar_size),f'{bar_type}.{bar_size}.{os.path.basename(file)}'))
             for file in csv_files for bar_size in bar_sizes]
    return tasks

# %%
def run_tasks_parallell(tasks: List[Tuple[str, str, int, str]])->None:
    with ProgressBar():
        db.from_sequence(tasks).map(lambda t: build_standard_bars(t[0], t[1], t[2], t[3])).compute()

# %%
csv_files = glob.glob('/data/csv/*XMR_USD*.csv')

# %%
csv_files
# Out:
# ['/data/csv/MXC.Spot.XMR_USDT.csv',
#  '/data/csv/Kraken.Spot.XMR_USD.csv',
#  '/data/csv/Binance.Swap.XMR_USDT.csv',
#  '/data/csv/OKEx.Swap.XMR_USD.csv',
#  '/data/csv/OKEx.Swap.XMR_USDT.csv',
#  '/data/csv/Binance.Spot.XMR_USDT.csv',
#  '/data/csv/Huobi.Spot.XMR_USDT.csv',
#  '/data/csv/Bitfinex.Spot.XMR_USD.csv',
#  '/data/csv/OKEx.Spot.XMR_USDT.csv']

# %%
tasks = generate_tasks(
    csv_files,
    'TimeBar',
    [10000, 60000],
    '/data/bars/TimeBar',
) + generate_tasks(
    csv_files,
    'TickBar',
    [4, 8],
    '/data/bars/TickBar',
) + generate_tasks(
    csv_files,
    'VolumeBar',
    [10, 100],
    '/data/bars/VolumeBar',
) + generate_tasks(
    csv_files,
    'DollarBar',
    [1000, 10000],
    '/data/bars/DollarBar',
)

# %%
len(tasks)
# Out:
# 72

# %%
run_tasks_parallell(tasks)
# Out:
# [########################################] | 100% Completed | 47min 47.3s

# %% [markdown]
# ## References
#
# * [Tick, Volume, Dollar Volume Bars.ipynb](https://github.com/BlackArbsCEO/Adv_Fin_ML_Exercises/blob/master/notebooks/Tick%2C%20Volume%2C%20Dollar%20Volume%20Bars.ipynb)
